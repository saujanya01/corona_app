# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("https://www.ecdc.europa.eu/sites/default/files/documents/COVID-19-geographic-disbtribution-worldwide-2020-03-28.xlsx")

# %%
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2018'],
#       dtype='object')

# %%
df = df.rename({'countriesAndTerritories':'location'},axis="columns")

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'Andorra', 'Argentina',
#        'Antigua_and_Barbuda', 'Algeria', 'Anguilla', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia_and_Herzegovina', 'Brazil',
#        'British_Virgin_Islands', 'Brunei_Darussalam', 'Bulgaria',
#        'Burkina_Faso', 'Cambodia', 'Cameroon', 'Canada', 'Cape_Verde',
#        'Cases_on_an_international_conveyance_Japan', 'Cayman_Islands',
#        'Central_African_Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Congo', 'Costa_Rica', 'Cote_dIvoire', 'Croatia', 'Cuba',
#        'Curaçao', 'Cyprus', 'Czech_Republic',
#        'Democratic_Republic_of_the_Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican_Republic', 'Ecuador', 'Egypt',
#        'El_Salvador', 'Equatorial_Guinea', 'Eritrea', 'Estonia',
# ...

# %%
# def cumulative(l):
#     f=[]
#     f=[sum(l[0:i+1]) for i in range(0,len(l))]
#     return (f)

# name='India'
# dates = df[df['location']==str(name)]['dateRep'].tolist()[::-1]
# date = [i.date() for i in dates]
# cases = df[df['location']==str(name)]['cases'].tolist()[::-1]
# deaths = df[df['location']==str(name)]['deaths'].tolist()[::-1]
# case = cumulative(cases)
# death = cumulative(deaths)
# i = len(case)-case[::-1].index(0)
# date[i-1:]
# case[i-1:]
# death[i-1:]

# %%
len(df[df['location']=='China']['dateRep'].unique())
# Out:
# 89

# %%
df['dateRep'][1493]
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
df[df['dateRep']==('2019-12-31 00:00:00')]['cases'].sum()
# Out:
# 27

# %%
l = df['dateRep'].unique()

# %%
l.sort()

# %%
str(l[0]).split('T')[0]
# Out:
# '2019-12-31'

# %%
df[df['dateRep']==l[87]]['cases'].sum()
# Out:
# 60090

# %%
l=df['dateRep'].unique()
l.sort()
wrld_cases = {}
wrld_deaths = {}
d=0
c=0
for i in l:
    d=d+df[df['dateRep']==i]['deaths'].sum()
    c=c+df[df['dateRep']==i]['cases'].sum()
    wrld_cases[str(i).split('T')[0]]=str(c)
    wrld_deaths[str(i).split('T')[0]]=str(d)
print(wrld_cases)
print("------------------------------------------------")
print(wrld_deaths)
# Out:
# {'2019-12-31': '27', '2020-01-01': '27', '2020-01-02': '27', '2020-01-03': '44', '2020-01-04': '44', '2020-01-05': '59', '2020-01-06': '59', '2020-01-07': '59', '2020-01-08': '59', '2020-01-09': '59', '2020-01-10': '59', '2020-01-11': '59', '2020-01-12': '59', '2020-01-13': '60', '2020-01-14': '60', '2020-01-15': '61', '2020-01-16': '61', '2020-01-17': '66', '2020-01-18': '83', '2020-01-19': '219', '2020-01-20': '239', '2020-01-21': '392', '2020-01-22': '534', '2020-01-23': '631', '2020-01-24': '897', '2020-01-25': '1350', '2020-01-26': '2023', '2020-01-27': '2820', '2020-01-28': '4587', '2020-01-29': '6067', '2020-01-30': '7823', '2020-01-31': '9826', '2020-02-01': '11946', '2020-02-02': '14554', '2020-02-03': '17372', '2020-02-04': '20615', '2020-02-05': '24522', '2020-02-06': '28273', '2020-02-07': '31491', '2020-02-08': '34933', '2020-02-09': '37552', '2020-02-10': '40540', '2020-02-11': '43105', '2020-02-12': '45177', '2020-02-13': '60328', '2020-02-14': '64543', '2020-02-15': '
# ...

# %%
df
# Out:
#         dateRep  day  month  year  cases  deaths     location geoId  \
# 0    2020-03-28   28      3  2020     16       1  Afghanistan    AF
# 1    2020-03-27   27      3  2020      0       0  Afghanistan    AF
# 2    2020-03-26   26      3  2020     33       0  Afghanistan    AF
# 3    2020-03-25   25      3  2020      2       0  Afghanistan    AF
# 4    2020-03-24   24      3  2020      6       1  Afghanistan    AF
# 5    2020-03-23   23      3  2020     10       0  Afghanistan    AF
# 6    2020-03-22   22      3  2020      0       0  Afghanistan    AF
# 7    2020-03-21   21      3  2020      2       0  Afghanistan    AF
# 8    2020-03-20   20      3  2020      0       0  Afghanistan    AF
# 9    2020-03-19   19      3  2020      0       0  Afghanistan    AF
# 10   2020-03-18   18      3  2020      1       0  Afghanistan    AF
# 11   2020-03-17   17      3  2020      5       0  Afghanistan    AF
# 12   2020-03-16   16      3  2020      6       0  Afghanistan    AF
# ...

# %%
l = df.location.unique()
geoid=[]
cntcode=[]
for i in range(0,len(l)):
    cntcode.append(df[df['location']==l[i]]['countryterritoryCode'].tolist()[0])
    geoid.append(df[df['location']==l[i]]['geoId'].tolist()[0])

# %%
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths', 'location',
#        'geoId', 'countryterritoryCode', 'popData2018'],
#       dtype='object')

# %%
cntcode
# Out:
# ['AFG',
#  'AGO',
#  'ALB',
#  'AND',
#  'ARG',
#  'ATG',
#  'DZA',
#  nan,
#  'ARM',
#  'ABW',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BHS',
#  'BHR',
#  'BGD',
#  'BRB',
#  'BLR',
#  'BEL',
#  'BLZ',
#  'BEN',
#  'BMU',
#  'BTN',
#  'BOL',
#  'BIH',
#  'BRA',
#  'VGB',
#  'BRN',
#  'BGR',
#  'BFA',
#  'KHM',
#  'CMR',
#  'CAN',
#  'CPV',
#  nan,
#  'CYM',
#  'CAF',
#  'TCD',
#  'CHL',
#  'CHN',
#  'COL',
#  'COG',
#  'CRI',
#  'CIV',
#  'HRV',
#  'CUB',
#  'CUW',
#  'CYP',
#  'CZE',
#  'COD',
#  'DNK',
#  'DJI',
#  'DMA',
#  'DOM',
#  'ECU',
#  'EGY',
#  'SLV',
#  'GNQ',
#  'ERI',
#  'EST',
#  'SWZ',
#  'ETH',
#  'FRO',
#  'FJI',
#  'FIN',
#  'FRA',
#  'PYF',
#  'GAB',
#  'GMB',
#  'GEO',
#  'DEU',
#  'GHA',
#  'GIB',
#  'GRC',
#  'GRL',
#  'GRD',
#  'GUM',
#  'GTM',
#  'GGY',
#  'GIN',
#  'GNB',
#  'GUY',
#  'HTI',
#  'VAT',
#  'HND',
#  'HUN',
#  'ISL',
#  'IND',
#  'IDN',
#  'IRN',
#  'IRQ',
#  'IRL',
#  'IMN',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JPN',
#  'JEY',
#  'JOR',
#  'KAZ',
# ...

# %%
geoid
# Out:
# ['AF',
#  'AO',
#  'AL',
#  'AD',
#  'AR',
#  'AG',
#  'DZ',
#  'AI',
#  'AM',
#  'AW',
#  'AU',
#  'AT',
#  'AZ',
#  'BS',
#  'BH',
#  'BD',
#  'BB',
#  'BY',
#  'BE',
#  'BZ',
#  'BJ',
#  'BM',
#  'BT',
#  'BO',
#  'BA',
#  'BR',
#  'VG',
#  'BN',
#  'BG',
#  'BF',
#  'KH',
#  'CM',
#  'CA',
#  'CV',
#  'JPG11668',
#  'KY',
#  'CF',
#  'TD',
#  'CL',
#  'CN',
#  'CO',
#  'CG',
#  'CR',
#  'CI',
#  'HR',
#  'CU',
#  'CW',
#  'CY',
#  'CZ',
#  'CD',
#  'DK',
#  'DJ',
#  'DM',
#  'DO',
#  'EC',
#  'EG',
#  'SV',
#  'GQ',
#  'ER',
#  'EE',
#  'SZ',
#  'ET',
#  'FO',
#  'FJ',
#  'FI',
#  'FR',
#  'PF',
#  'GA',
#  'GM',
#  'GE',
#  'DE',
#  'GH',
#  'GI',
#  'EL',
#  'GL',
#  'GD',
#  'GU',
#  'GT',
#  'GG',
#  'GN',
#  'GW',
#  'GY',
#  'HT',
#  'VA',
#  'HN',
#  'HU',
#  'IS',
#  'IN',
#  'ID',
#  'IR',
#  'IQ',
#  'IE',
#  'IM',
#  'IL',
#  'IT',
#  'JM',
#  'JP',
#  'JE',
#  'JO',
#  'KZ',
#  'KE',
#  'XK',
#  'KW',
#  'KG',
#  'LA',
#  'LV',
#  'LB',
#  'LR',
#  'LY',
#  'LI',
# ...

# %%
l.tolist()
# Out:
# ['Afghanistan',
#  'Angola',
#  'Albania',
#  'Andorra',
#  'Argentina',
#  'Antigua_and_Barbuda',
#  'Algeria',
#  'Anguilla',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia_and_Herzegovina',
#  'Brazil',
#  'British_Virgin_Islands',
#  'Brunei_Darussalam',
#  'Bulgaria',
#  'Burkina_Faso',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape_Verde',
#  'Cases_on_an_international_conveyance_Japan',
#  'Cayman_Islands',
#  'Central_African_Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Costa_Rica',
#  'Cote_dIvoire',
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czech_Republic',
#  'Democratic_Republic_of_the_Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican_Republic',
#  'Ecuador',
#  'Egypt',
#  'El_Salvador',
#  'Equatorial_Guinea',
# ...

# %%
l = []
for i in df['location'].unique():
    d={'value':i,'data':df[df['location']==i]['geoId'].unique()[0]}
    l.append(d)

# %%
l
# Out:
# [{'value': 'Afghanistan', 'data': 'AF'},
#  {'value': 'Angola', 'data': 'AO'},
#  {'value': 'Albania', 'data': 'AL'},
#  {'value': 'Andorra', 'data': 'AD'},
#  {'value': 'Argentina', 'data': 'AR'},
#  {'value': 'Antigua_and_Barbuda', 'data': 'AG'},
#  {'value': 'Algeria', 'data': 'DZ'},
#  {'value': 'Anguilla', 'data': 'AI'},
#  {'value': 'Armenia', 'data': 'AM'},
#  {'value': 'Aruba', 'data': 'AW'},
#  {'value': 'Australia', 'data': 'AU'},
#  {'value': 'Austria', 'data': 'AT'},
#  {'value': 'Azerbaijan', 'data': 'AZ'},
#  {'value': 'Bahamas', 'data': 'BS'},
#  {'value': 'Bahrain', 'data': 'BH'},
#  {'value': 'Bangladesh', 'data': 'BD'},
#  {'value': 'Barbados', 'data': 'BB'},
#  {'value': 'Belarus', 'data': 'BY'},
#  {'value': 'Belgium', 'data': 'BE'},
#  {'value': 'Belize', 'data': 'BZ'},
#  {'value': 'Benin', 'data': 'BJ'},
#  {'value': 'Bermuda', 'data': 'BM'},
#  {'value': 'Bhutan', 'data': 'BT'},
#  {'value': 'Bolivia', 'data': 'BO'},
# ...
